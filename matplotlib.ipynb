# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[2,5,7])

# %%
plt.title("Data")
plt.ylabel("Y")
plt.xlabel("X")
plt.plot([1,2,3],[2,5,7])

# %%
from matplotlib import style
style.use('ggplot')
x = [ 1,10,30]
y = [ 10,100,30]
plt.plot(x,y)
plt.legend
